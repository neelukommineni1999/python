# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("PartitionsPractice").getOrCreate()

df = spark.read.csv(
    "events.csv",
    header=True,
    inferSchema=True
)

print("Number of partitions:", df.rdd.getNumPartitions())
# Out:
# Number of partitions: 1

# %%
df_repartitioned = df.repartition(4)

df_repartitioned.cache()

df_repartitioned.show()

total_rows = df_repartitioned.count()

print("Total rows:", total_rows)
# Out:
# +-------+----------+-------+----------+
# |user_id|event_type|country|event_date|
# +-------+----------+-------+----------+
# |    102|  purchase|  India|2025-05-01|
# |    103|    logout|    USA|2025-05-02|
# |    105|  purchase|  India|2025-05-03|
# |    104|     login| Canada|2025-05-02|
# |    101|     login|    USA|2025-05-01|
# +-------+----------+-------+----------+
#
# Total rows: 5
