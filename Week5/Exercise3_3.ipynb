# %%
DataFrames are preferred because they are simple to use and work faster than RDDs. 
They need less coding and Spark automatically improves their performance.
DataFrames also allow us to use SQL queries easily, so most modern Spark projects use DataFrames instead of RDDs.
